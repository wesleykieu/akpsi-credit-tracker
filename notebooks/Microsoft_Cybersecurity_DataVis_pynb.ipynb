# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Correct filename from os.listdir #
file_path = "GUIDE_Train.csv"

# Load only the first 1,000,000 rows
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "Microsoft/microsoft-security-incident-prediction",
    file_path,
    pandas_kwargs={"nrows": 1_000_000}
).sample(100000)

print("Shape:", df.shape)
print("First 5 records:\n", df.head())
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/Microsoft/microsoft-security-incident-prediction?dataset_version_number=1&file_name=GUIDE_Train.csv...
# 100%|██████████| 357M/357M [00:10<00:00, 35.2MB/s]
# Extracting zip of GUIDE_Train.csv...
# /usr/local/lib/python3.12/dist-packages/kagglehub/pandas_datasets.py:91: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = read_function(
# Shape: (100000, 45)
# First 5 records:
#                     Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 808535  1108101565707   2113       68383   834074  2024-06-06T04:47:56.000Z
# 37575    798863918730     41       50752    30314  2024-06-14T17:37:22.000Z
# 893763  1142461304534     12         247   464757  2024-06-11T10:36:30.000Z
# 864454   652835031772     40       16867    17509  2024-06-03T05:48:56.000Z
# 66392    506806143851    473      577305  1619434  2024-06-12T22:26:22.000Z
#
#         DetectorId  AlertTitle           Category MitreTechniques  \
# 808535          19          15      InitialAccess             NaN
# 37575           32       13432       Exfiltration             NaN
# 893763          74          55  CommandAndControl     T1071;T1048
# 864454           1           1      InitialAccess       T1566.002
# 66392          118          98      InitialAccess             NaN
#
#          IncidentGrade  ... ResourceType Roles OSFamily OSVersion  \
# 808535   FalsePositive  ...          NaN   NaN        5        66
# 37575     TruePositive  ...          NaN   NaN        5        66
# 893763  BenignPositive  ...          NaN   NaN        5        66
# 864454  BenignPositive  ...          NaN   NaN        5        66
# 66392   BenignPositive  ...          NaN   NaN        5        66
#
#         AntispamDirection  SuspicionLevel  LastVerdict  CountryCode  State  \
# 808535                NaN             NaN          NaN          242   1445
# 37575                 NaN             NaN          NaN          242   1445
# 893763                NaN             NaN          NaN          242   1445
# 864454                NaN             NaN          NaN          242   1445
# 66392                 NaN             NaN          NaN          242   1445
#
#          City
# 808535  10630
# 37575   10630
# 893763  10630
# 864454  10630
# 66392   10630
#
# [5 rows x 45 columns]

# %%
df.head()
# Out:
#                    Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 808535  1108101565707   2113       68383   834074  2024-06-06T04:47:56.000Z
# 37575    798863918730     41       50752    30314  2024-06-14T17:37:22.000Z
# 893763  1142461304534     12         247   464757  2024-06-11T10:36:30.000Z
# 864454   652835031772     40       16867    17509  2024-06-03T05:48:56.000Z
# 66392    506806143851    473      577305  1619434  2024-06-12T22:26:22.000Z
#
#         DetectorId  AlertTitle           Category MitreTechniques  \
# 808535          19          15      InitialAccess             NaN
# 37575           32       13432       Exfiltration             NaN
# 893763          74          55  CommandAndControl     T1071;T1048
# 864454           1           1      InitialAccess       T1566.002
# 66392          118          98      InitialAccess             NaN
#
#          IncidentGrade  ... ResourceType Roles OSFamily OSVersion  \
# 808535   FalsePositive  ...          NaN   NaN        5        66
# 37575     TruePositive  ...          NaN   NaN        5        66
# 893763  BenignPositive  ...          NaN   NaN        5        66
# 864454  BenignPositive  ...          NaN   NaN        5        66
# 66392   BenignPositive  ...          NaN   NaN        5        66
#
#         AntispamDirection  SuspicionLevel  LastVerdict  CountryCode  State  \
# 808535                NaN             NaN          NaN          242   1445
# 37575                 NaN             NaN          NaN          242   1445
# 893763                NaN             NaN          NaN          242   1445
# 864454                NaN             NaN          NaN          242   1445
# 66392                 NaN             NaN          NaN          242   1445
#
#          City
# 808535  10630
# 37575   10630
# 893763  10630
# 864454  10630
# 66392   10630
#
# [5 rows x 45 columns]

# %%
df.shape
# Out:
# (100000, 45)
